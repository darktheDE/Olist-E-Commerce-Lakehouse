# %% [markdown]
# # Spike Test: Spark to MinIO Connection
# This notebook verifies that `spark` can read and write to the MinIO object storage using `delta` format.

# %%
import sys
from pathlib import Path

# Thêm đường dẫn thư mục gốc vào sys.path để gọi được src modules
PROJECT_ROOT = Path().resolve().parents[0]
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# Gọi module bạn đã cấu hình sẵn trong src
from src.spark_session import get_spark_session

print("Đang khởi tạo Spark Session kết nối với Hive Metastore...")
spark = get_spark_session("Notebook_Hive_Testing")
print("Khởi tạo thành công!")
# Out:
# Đang khởi tạo Spark Session kết nối với Hive Metastore...
# ERROR:root:KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "d:\Work\Freelance\Olist-E-Commerce-Lakehouse\.venv\Lib\site-packages\py4j\java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Work\Freelance\Olist-E-Commerce-Lakehouse\.venv\Lib\site-packages\py4j\clientserver.py", line 535, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#                           ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\VIP\AppData\Local\Programs\Python\Python312\Lib\socket.py", line 720, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 13
# ...

# %%
# Xem danh sách các Database hiện có (Bảo gồm default)
spark.sql("SHOW DATABASES").show()

# Liệt kê tất cả các External Tables lưu trên Hive
spark.sql("SHOW TABLES IN default").show(truncate=False)
# Out:
# +---------+
# |namespace|
# +---------+
# |  default|
# +---------+
#
# +---------+-------------------------------+-----------+
# |namespace|tableName                      |isTemporary|
# +---------+-------------------------------+-----------+
# |default  |olist_category_name_translation|false      |
# |default  |olist_customers                |false      |
# |default  |olist_geolocation              |false      |
# |default  |olist_order_items              |false      |
# |default  |olist_order_payments           |false      |
# |default  |olist_orders                   |false      |
# |default  |olist_products                 |false      |
# |default  |olist_reviews                  |false      |
# |default  |olist_sellers                  |false      |
# +---------+-------------------------------+-----------+

# %%
# Đếm số lượng record (Sẽ hiển thị 99,441 records)
count_df = spark.sql("SELECT COUNT(*) AS total_orders FROM default.olist_orders")
count_df.show()

# Đọc thử 5 dòng dữ liệu đầu tiên và chuyển thành Pandas DataFrame để hiển thị đẹp mắt
spark.sql("""
    SELECT order_id, customer_id, order_status, order_purchase_timestamp 
    FROM default.olist_orders 
    WHERE order_status = 'delivered'
    LIMIT 5
""").toPandas()
# Out:
# +------------+
# |total_orders|
# +------------+
# |       99441|
# +------------+
#                            order_id                       customer_id  \
# 0  995392413cee61cc1fcec9807870ea8c  4bf24904ec428325abad2791fcca1aff
# 1  b39de9ed2bb8fd08a970e4517c698824  ed18b557140ff674f36cbcf73921dbbe
# 2  b1a88554eb1f7f68627549e26257b583  5cf799d0ac88e1d328434a595c015efa
# 3  fe2ac30768e07e362b649951cc625144  be07f06f183227b5c2b31c30fbb4f382
# 4  460673777918e7a42a262293341ae7d5  6f352988122e277e645d36a012e66bcb
#
#   order_status order_purchase_timestamp
# 0    delivered      2017-09-04 15:24:05
# 1    delivered      2018-03-27 02:15:17
# 2    delivered      2018-06-12 19:19:56
# 3    delivered      2017-01-16 09:41:18
# 4    delivered      2018-02-07 15:38:41
